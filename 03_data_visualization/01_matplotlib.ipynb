# %% [markdown]
# # Matplotlib
#
# https://kr.mathworks.com/products/matlab-online.html
#
# https://matplotlib.org/3.5.3/index.html
#
# https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html
#
#
# | **특징**       | **Matlab**                          | **Matplotlib**                     | **Matplotlib.pyplot**             |
# |----------------|-------------------------------------|------------------------------------|-----------------------------------|
# | **유형**       | 상용 소프트웨어                     | 파이썬 시각화 라이브러리           | Matplotlib의 서브모듈             |
# | **언어**       | Matlab 전용 스크립팅 언어           | 파이썬                             | 파이썬                            |
# | **사용 목적**  | 과학적 계산, 시뮬레이션, 시각화     | 2D/3D 플롯, 과학적 시각화          | 간단한 플롯 생성, Matlab 스타일   |
# | **라이선스**   | 상업용 (유료)                       | 오픈 소스 (무료)                   | 오픈 소스 (무료)                  |
# | **유연성**     | 매우 직관적인 그래픽 도구           | 고급 시각화 가능, 유연함           | 간편한 함수 기반 플롯             |
#
#
#
# - [Plot Types](https://matplotlib.org/3.5.3/plot_types/index.html#plots-of-arrays-and-fields)
# - [Tutorials (Introductory | Intermediate | Advanced | Colors | Provisional | Text | Toolkit)](https://matplotlib.org/3.5.3/tutorials/index.html)

# %% [markdown]
# ## ⚙️환경설정

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in C:\Users\playdata2\miniforge3\Lib\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\playdata2\miniforge3\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\playdata2\miniforge3\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\playdata2\miniforge3\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\playdata2\miniforge3\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in C:\Users\playdata2\miniforge3\Lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in C:\Users\playdata2\miniforge3\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in C:\Users\playdata2\miniforge3\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\playdata2\miniforge3\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\playdata2\miniforge3\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\playdata2\miniforge3\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib

matplotlib.__version__
# Out:
# '3.11.0'

# %%
# pyplot은 Matplotlib에서 그래프를 그릴 때 가장 많이 사용하는 모듈
import matplotlib.pyplot as plt

# plt.plot() : 선 그래프 그리기
plt.plot([1, 2, 3, 4]) # f(x) = x + 1

plt.show() # 그래프 출력

# %%
X = [1, 2, 3]
Y = [2, 4, 6]
plt.plot(X, Y)

# 표 제목
plt.title('Hello Matplotlib')

plt.show()

# %% [markdown]
# ## Figure와 Axes
#
# https://sigmadream.github.io/practice-matplotlib/note/part_01.html
#
#
# - Figure(피겨): 전체 그림을 그리는 틀 (캔버스)
# - Axes(엑시즈): 그래프가 실제로 그려지는 영역 (데이터와 축을 포함)
#
# **주요명령어**
# - 새 figure 생성하기 `plt.figure()`
# - 새 axes 생성하기 `plt.axes()`
# - 현재 axes 가져오기(get_current_axes) `ax = plt.gca()`
# - figure와 그에 속한 axes 동시에 생성하기 `fig, ax = plt.subplots()`
#
# ![](https://d.pr/i/nggnqj+)
#
# | 용어         | 의미            | 비유     |
# | ---------- | ------------- | ------ |
# | Figure     | 전체 그림 영역      | 도화지    |
# | Axes       | 실제 그래프 하나의 영역 | 그래프 칸  |
# | Axis       | x축, y축        | 눈금자    |
# | Tick       | 축의 눈금         | 눈금 선   |
# | Tick label | 눈금에 붙은 숫자/글자  | 눈금 값   |
# | Spine      | 그래프 테두리       | 액자 테두리 |
# | Legend     | 범례            | 설명표    |

# %%
# figure == 전체 틀
# axes == 실제 그래프가 그려지는 영역

# 새 Figure를 만들고 선 그래프 그리기

# figsize=(8, 6) : 피겨 가로 8인치, 세로 6인치
# facecolor='pink' : 배경색 핑크
plt.figure(figsize=(8, 6), facecolor='pink')

# 현재 활성화된 axes를 가져오기, 없으면 생성
ax = plt.gca() # get current axes 약자
X = [1, 2, 3]
Y = [2, 4, 6]

ax.plot(X, Y, marker='o', linewidth=3) # 선 그래프
ax.bar(X, Y, color='orange', alpha=0.5, width=0.3) # 막대 그래프

plt.title('Figure - Axes')

plt.show()

# %% [markdown]
# ## plot
